# %%
import matplotlib.pyplot as plt
from odeanimate.domains import Interval
from odeanimate.vector import Vector2D
from odeanimate.plots.vectors import vector_2d_tails, vector_2d_single
from odeanimate.plots.axes import cartesian_axes

# %%
vectors = [
    Vector2D(1, 1),
    Vector2D(1, -1),
    Vector2D(-2, -2),
    Vector2D(-2, 2),
    Vector2D(2, 2),
    Vector2D(1, -1)/2
]

*vectors, sum(vectors, start=Vector2D(0,0))
# Out:
# (Vector2D(1, 1),
#  Vector2D(1, -1),
#  Vector2D(-2, -2),
#  Vector2D(-2, 2),
#  Vector2D(2, 2),
#  Vector2D(0.5, -0.5),
#  Vector2D(0.5, 1.5))

# %%
interval = Interval(-2, 2)
step = 0.5
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot()
ax = cartesian_axes(ax, interval)
ax = vector_2d_tails(ax, *vectors, labels=["A", "B", "C", "D", "E", "F"])
ax = vector_2d_single(ax, sum(vectors, start=Vector2D(0,0)), label="A  + B + C + D + E + F")
